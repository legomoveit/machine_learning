# %%
pip3 install pandas
# Out:
#   File "C:\Users\지상민\AppData\Local\Temp/ipykernel_24260/3029356636.py", line 1
#     pip3 install pandas
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd 
import pymysql 
import pymysql.cursors
import numpy as np
 
ssh_host = '3.36.21.112'
ssh_port = '21'
conn_practice = pymysql.connect(host='3.36.21.112', user='root', password='ckUdC17yqltr', db='practice')
conn_resource = pymysql.connect(host='3.36.21.112', user='root', password='ckUdC17yqltr', db='resource')
conn_testserver = pymysql.connect(host='3.36.21.112', user='root', password='ckUdC17yqltr', db='saladpet')
## 2. 엑셀 전처리 시 필요한 SQL DB 불러오기 작업 ##

cursor_practice = conn_practice.cursor()
cursor_resource = conn_resource.cursor() #dictionary 형태로 결과 반환 원해 -> pymysql.cursors.Dictcursor을 ()에 넣어줌.
cursor_testserver = conn_testserver.cursor()

sql_data_p = "select * from pracitce.data_p"

data_p = pd.read_sql(sql_data_p, conn_practice)
 # 열이 포함된 형태로 select하려면 이 문자형태로 진행 

data_p
#supplement_type.set_index("type_id", inplace = True ) # inplace = true는 변경 사항을 그대로 객체에 다시 저장한다.
#map_product_cate.set_index("mc_pk", inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# C:\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# C:\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# C:\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# C:\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# C:\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# C:\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# C:\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# C:\anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# C:\anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# ProgrammingError: (1146, "Table 'pracitce.data_p' doesn't exist")
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-24-02cba2b38f34> in <module>
#      17 sql_data_p = "select * from pracitce.data_p"
#      18
# ---> 19 data_p = pd.read_sql(sql_data_p, conn_practice)
#      20  # 열이 포함된 형태로 select하려면 이 문자형태로 진행
#      21
#
# C:\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     481
#     482     if isinstance(pandas_sql, SQLiteDatabase):
# --> 483         return pandas_sql.read_query(
#     484             sql,
#     485             index_col=index_col,
#
# C:\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1725
#    1726         args = _convert_params(sql, params)
# -> 1727         cursor = self.execute(*args)
#    1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#
# C:\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1691
#    1692             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1693             raise ex from exc
#    1694
#    1695     @staticmethod
#
# DatabaseError: Execution failed on sql 'select * from pracitce.data_p': (1146, "Table 'pracitce.data_p' doesn't exist")

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sns.lineplot(data = data_money, x='weight', y='score_four', hue = 'parent_category')
# Out:
# <AxesSubplot:xlabel='weight', ylabel='score_four'>
