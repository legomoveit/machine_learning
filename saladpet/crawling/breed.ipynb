# %%
import time
from selenium import webdriver
import re
import pandas as pd

driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(2)
driver.get('https://www.akc.org/dog-breeds/')

# %%
li_tags = driver.find_elements_by_css_selector("div[class='grid-col']")
li_tags.pop()
li_tags.pop()
len(li_tags)

li_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ccfe8ba006795f3e4602886e4a4197d", element="670c5b94-8e15-4e7e-9b50-ab93a27126c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ccfe8ba006795f3e4602886e4a4197d", element="c9026bea-8160-4bf6-b84f-03dbd613b276")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ccfe8ba006795f3e4602886e4a4197d", element="5d15cd1f-687f-4d8f-b9e3-5543a766c651")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ccfe8ba006795f3e4602886e4a4197d", element="051e96fd-280f-4786-aaa4-ab48049d9520")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ccfe8ba006795f3e4602886e4a4197d", element="ff129bed-3f02-4610-96c1-dc018c5c5ed5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ccfe8ba006795f3e4602886e4a4197d", element="c0d6271a-b6c0-426e-9add-744d4bbd0023")>,
# ...

# %%
detail_tag =  li_tags[0]
a = detail_tag.find_element_by_css_selector("div")
a_2 = a.get_attribute('data-title')

b = detail_tag.find_element_by_css_selector('div > a > div > img')
b_2 = b.get_attribute('src')
print(a_2)
print(b_2)
# Out:
# Affenpinscher
# https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/30174107/Affenpinscher-copy-400x267.jpg

# %%
breed = { 'breed_name', 'breed_site', 'breed_image'}
breed = { 'breed_name' : "hi", 'breed_site' : "bye", 'breed_image' : 3}
breed
# Out:
# {'breed_name': 'hi', 'breed_site': 'bye', 'breed_image': 3}

# %%
breed = []

for detail_tag in li_tags :
    a = detail_tag.find_element_by_css_selector("div")
    a_2 = a.get_attribute('data-title')
    b = detail_tag.find_element_by_css_selector("div > a")
    b_2 = b.get_attribute('href')

    c = detail_tag.find_element_by_css_selector("div > a > div > img ")
    c_2 = c.get_attribute("src")
    breed.append( [a_2, b_2, c_2] )

# %%
len(breed)
# Out:
# 282

# %%
breed
# Out:
# [['Affenpinscher',
#   'https://www.akc.org/dog-breeds/affenpinscher/',
#   'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/30174107/Affenpinscher-copy-400x267.jpg'],
#  ['Afghan Hound',
#   'https://www.akc.org/dog-breeds/afghan-hound/',
#   'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/26151212/Afghan-Hound-standing-in-a-garden-400x267.jpg'],
#  ['Airedale Terrier',
#   'https://www.akc.org/dog-breeds/airedale-terrier/',
#   'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/30202205/Airedale-Terrier-standing-stacked-outdoors-400x267.jpg'],
#  ['Akita',
#   'https://www.akc.org/dog-breeds/akita/',
#   'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/13001904/Akita-On-White-01-400x267.jpg'],
#  ['Alaskan Klee Kai',
#   'https://www.akc.org/dog-breeds/alaskan-klee-kai/',
# ...

# %%
breed[0][1]
# Out:
# 'https://www.akc.org/dog-breeds/affenpinscher/'

# %%
import time
from selenium import webdriver
import re
import pandas as pd

driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(2)

# %%
def AKC ( name, number) :
    tagging = tag[number].find_elements_by_css_selector("p[class = 'f-16 my0 lh-solid breed-page__hero__overview__subtitle']")
    if len(tagging) > 1 :
        final['{}_male'.format(name)] = str(tagging[0].text)
        final['{}_female'.format(name)] = str(tagging[1].text)
    else :
        final['{}_male'.format(name)] = str(tagging[0].text)
        final['{}_female'.format(name)] = str(tagging[0].text)

# %%
def AKC ( name, number) :
    tagging = tag[number].find_elements_by_css_selector("p[class = 'f-16 my0 lh-solid breed-page__hero__overview__subtitle']")
    if len(tagging) == 2 :
        first = str(tagging[0].text)
        second = str(tagging[1].text)
        final['{}_male-min'.format(name)] = first[0 : first.find('-')]
        final['{}_male-max'.format(name)] = first[first.find('-') + 1 : first.find('p')]
        final['{}_female_min'.format(name)] = str(tagging[1].text)
        final['{}_female_max'.format(name)] = str(tagging[1].text)
    elif len(tagging) == 1:
        final['{}_male'.format(name)] = str(tagging[0].text)
        final['{}_female'.format(name)] = str(tagging[0].text)


    
# 예외사항 : weight 에 slightly smaller (female)

# %%
import random
import pandas as pd 

df = pd.DataFrame()

for i, cell in enumerate (breed[196:]) :
    driver.get(cell[1])
    time.sleep(random.randint(2, 3))
    tag = driver.find_elements_by_css_selector("div[class = 'flex breed-page__hero__overview__icon-block']")
    final = { 'breed_name' : cell[0] }
    # AKC ('height', 0)
    # AKC ('weight', 1)
    # AKC ('life_span', 2)

    male_number = ["-","male"]
    female_number = ["-","female"]

    toy_number = ["-", "toy"]
    miniature_number = ["-", "miniature"]
    standard_number = ["-", "standard"]
    

    #height
    tagging = tag[0].find_elements_by_css_selector("p[class = 'f-16 my0 lh-solid breed-page__hero__overview__subtitle']")
    if len(tagging) == 2 :
            first = str(tagging[0].text)
            second = str(tagging[1].text)

            if all(s in first for s in male_number) and all(t in second for t in female_number):
                final['height_male_min'] = first[0 : first.find('-')]
                final['height_male_max'] = first[first.find('-') + 1 : first.find('i')]
                final['height_female_min'] = second[0 : second.find('-')]
                final['height_female_max'] = second[second.find('-') + 1 : second.find('i')]
            else :
                final['height_male_min'] = first[0 : first.find('i')]
                final['height_male_max'] = first[0 : first.find('i')]
                final['height_female_min'] = second[0 : second.find('i')]
                final['height_female_max'] = second[0 : second.find('i')]

    elif len(tagging) == 1:
            first = str(tagging[0].text)
            if "-" in first :
                final['height_male_min'] = first[0 : first.find('-')]
                final['height_male_max'] = first[first.find('-') + 1 : first.find('i')]
                final['height_female_min'] = first[0 : first.find('-')]
                final['height_female_max'] = first[first.find('-') + 1 : first.find('i')]
            if "-" not in first :
                final['height_male_min'] = first[0 : first.find('i')]
                final['height_male_max'] =  first[0 : first.find('i')]
                final['height_female_min'] =  first[0 : first.find('i')]
                final['height_female_max'] =  first[0 : first.find('i')]

    elif len(tagging) == 3:
            first = str(tagging[0].text)
            second = str(tagging[1].text)
            third = str(tagging[2].text)
            if all(s in first for s in toy_number) and all(s in first for s in miniature_number) and all(s in first for s in standard_number):
                final['height_toy_min'] = first[0 : first.find('-')]
                final['height_toy_max'] = first[first.find('-') + 1 : first.find('i')]
                final['height_miniature_min'] = second[0 : second.find('-')]
                final['height_miniature_max'] = second[second.find('-') + 1 : second.find('i')]
                final['height_standard_min'] = third[0 : third.find('-')]
                final['height_standard_max'] = third[third.find('-') + 1 : third.find('i')]
            else :
                final['height_toy_min'] = first[0 : first.find('i')]
                final['height_toy_max'] = first[0 : first.find('i')]
                final['height_miniature_min'] = second[0 : second.find('i')]
                final['height_miniature_max'] = second[0 : second.find('i')]
                final['height_standard_min'] = third[0 : third.find('i')]
                final['height_standard_max'] = third[0 : third.find('i')]

    #weight
    tagging = tag[1].find_elements_by_css_selector("p[class = 'f-16 my0 lh-solid breed-page__hero__overview__subtitle']")
    if len(tagging) == 2 :
            first = str(tagging[0].text)
            second = str(tagging[1].text)

            if all(s in first for s in male_number) and all(t in second for t in female_number):
                final['weight_male_min'] = first[0 : first.find('-')]
                final['weight_male_max'] = first[first.find('-') + 1 : first.find('p')]
                final['weight_female_min'] = second[0 : second.find('-')]
                final['weight_female_max'] = second[second.find('-') + 1 : second.find('p')]
            else :
                final['weight_male_min'] = first[0 : first.find('p')]
                final['weight_male_max'] = first[0 : first.find('p')]
                final['weight_female_min'] = second[0 : second.find('p')]
                final['weight_female_max'] = second[0 : second.find('p')]

    elif len(tagging) == 1:
            first = str(tagging[0].text)
            if "-" in first :
                final['weight_male_min'] = first[0 : first.find('-')]
                final['weight_male_max'] = first[first.find('-') + 1 : first.find('p')]
                final['weight_female_min'] = first[0 : first.find('-')]
                final['weight_female_max'] = first[first.find('-') + 1 : first.find('p')]
            if "-" not in first :
                final['weight_male_min'] = first[0 : first.find('p')]
                final['weight_male_max'] =  first[0 : first.find('p')]
                final['weight_female_min'] =  first[0 : first.find('p')]
                final['weight_female_max'] =  first[0 : first.find('p')]

    elif len(tagging) == 3:
            first = str(tagging[0].text)
            second = str(tagging[1].text)
            third = str(tagging[2].text)
            if all(s in first for s in toy_number) and all(s in first for s in miniature_number) and all(s in first for s in standard_number):
                final['weight_toy_min'] = first[0 : first.find('-')]
                final['weight_toy_max'] = first[first.find('-') + 1 : first.find('p')]
                final['weight_miniature_min'] = second[0 : second.find('-')]
                final['weight_miniature_max'] = second[second.find('-') + 1 : second.find('p')]
                final['weight_standard_min'] = third[0 : third.find('-')]
                final['weight_standard_max'] = third[third.find('-') + 1 : third.find('p')]
            else :
                final['weight_toy_min'] = first[0 : first.find('p')]
                final['weight_toy_max'] = first[0 : first.find('p')]
                final['weight_miniature_min'] = second[0 : second.find('p')]
                final['weight_miniature_max'] = second[0 : second.find('p')]
                final['weight_standard_min'] = third[0 : third.find('p')]
                final['weight_standard_max'] = third[0 : third.find('p')]

        

    #life_span
    tagging = tag[2].find_elements_by_css_selector("p[class = 'f-16 my0 lh-solid breed-page__hero__overview__subtitle']")
    if len(tagging) == 2 :
            first = str(tagging[0].text)
            second = str(tagging[1].text)

            if all(s in first for s in male_number) and all(t in second for t in female_number):
                final['lifespan_male_min'] = first[0 : first.find('-')]
                final['lifespan_male_max'] = first[first.find('-') + 1 : first.find('y')]
                final['lifespan_female_min'] = second[0 : second.find('-')]
                final['lifespan_female_max'] = second[second.find('-') + 1 : second.find('y')]
            else :
                final['lifespan_male_min'] = first[0 : first.find('y')]
                final['lifespan_male_max'] = first[0 : first.find('y')]
                final['lifespan_female_min'] = second[0 : second.find('y')]
                final['lifespan_female_max'] = second[0 : second.find('y')]

    elif len(tagging) == 1:
            first = str(tagging[0].text)
            if "-" in first :
                final['lifespan_male_min'] = first[0 : first.find('-')]
                final['lifespan_male_max'] = first[first.find('-') + 1 : first.find('y')]
                final['lifespan_female_min'] = first[0 : first.find('-')]
                final['lifespan_female_max'] = first[first.find('-') + 1 : first.find('y')]
            if "-" not in first :
                final['lifespan_male_min'] = first[0 : first.find('y')]
                final['lifespan_male_max'] =  first[0 : first.find('y')]
                final['lifespan_female_min'] =  first[0 : first.find('y')]
                final['lifespan_female_max'] =  first[0 : first.find('y')]

    elif len(tagging) == 3:
            first = str(tagging[0].text)
            second = str(tagging[1].text)
            third = str(tagging[2].text)
            if all(s in first for s in toy_number) and all(s in first for s in miniature_number) and all(s in first for s in standard_number):
                final['lifespan_toy_min'] = first[0 : first.find('-')]
                final['lifespan_toy_max'] = first[first.find('-') + 1 : first.find('y')]
                final['lifespan_miniature_min'] = second[0 : second.find('-')]
                final['lifespan_miniature_max'] = second[second.find('-') + 1 : second.find('y')]
                final['lifespan_standard_min'] = third[0 : third.find('-')]
                final['lifespan_standard_max'] = third[third.find('-') + 1 : third.find('y')]
            else :
                final['lifespan_toy_min'] = first[0 : first.find('y')]
                final['lifespan_toy_max'] = first[0 : first.find('y')]
                final['lifespan_miniature_min'] = second[0 : second.find('y')]
                final['lifespan_miniature_max'] = second[0 : second.find('y')]
                final['lifespan_standard_min'] = third[0 : third.find('y')]
                final['lifespan_standard_max'] = third[0 : third.find('y')]


    df = df.append(final, ignore_index= True)
    print (df)
    time.sleep(random.randint(1, 2))
df.head()
# Out:
#   breed_name height_male_min height_male_max height_female_min  \
# 0    Pointer              25             28                 23
#
#   height_female_max weight_male_min weight_male_max weight_female_min  \
# 0               26               55             75                 45
#
#   weight_female_max lifespan_male_min lifespan_male_max lifespan_female_min  \
# 0               65                 12               17                   12
#
#   lifespan_female_max
# 0                 17
#                 breed_name height_male_min height_male_max height_female_min  \
# 0                  Pointer              25             28                 23
# 1  Polish Lowland Sheepdog              18             20                 17
#
#   height_female_max weight_male_min weight_male_max weight_female_min  \
# 0               26               55             75                 45
# 1               19               30             50                 30
#
# ...

# %%
df.to_excel('C:/import/breed_crawling_crazy66.xlsx', index = False)

# %%
height = tag[0].find_elements_by_css_selector("p[class = 'f-16 my0 lh-solid breed-page__hero__overview__subtitle']")

if len(height) > 1 :
    height_male = height[0].text
    height_female = height[1].text
else :
    height_male = height[0].text
    height_female = height[0].text

weight = tag[1].find_elements_by_css_selector("p[class = 'f-16 my0 lh-solid breed-page__hero__overview__subtitle']")

# %%
breed[215]
# Out:
# ['Rat Terrier',
#  'https://www.akc.org/dog-breeds/rat-terrier/',
#  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/12225148/Rat-Terrier-On-White-01-400x267.jpg']

# %%
# 확인해봐야될것

import random
import pandas as pd 

df = pd.DataFrame()

weight_crazy = ["More","more","under","Under","up","Up","Toy","Miniature","and","And","Standard","&","Mininum","mininum","slightly","Slightly"]


for i, cell in enumerate (breed[197:]) :
    driver.get(cell[1])
    time.sleep(random.randint(5, 6))
    tag = driver.find_elements_by_css_selector("div[class = 'flex breed-page__hero__overview__icon-block']")
    final = { 'breed_name' : cell[0] }
    

    #height--------------------------------------------------------------------------------------------
    tagging = tag[0].find_elements_by_css_selector("p[class = 'f-16 my0 lh-solid breed-page__hero__overview__subtitle']")
    if len(tagging) == 1 :
        first = str(tagging[0].text)
        if any(s in first for s in weight_crazy)  :
            final['crazy_height1'] = first

    if len(tagging) == 2 :
        first = str(tagging[0].text)
        second = str(tagging[1].text)
    
        if any(s in first for s in weight_crazy)  :
            final['crazy_height1'] = first
        if any(s in second for s in weight_crazy) :
            final['crazy_height2'] = second

    if len(tagging) == 3 :
        first = str(tagging[0].text)
        second = str(tagging[1].text)
        third = str(tagging[2].text)
        if any(s in first for s in weight_crazy)  :
            final['crazy_height1'] = first
        if any(s in second for s in weight_crazy) :
            final['crazy_height2'] = second
        if any(s in third for s in weight_crazy) :
            final['crazy_height3'] = third
    #weight-----------------------------------------------------------------------------------------------------
    tagging = tag[1].find_elements_by_css_selector("p[class = 'f-16 my0 lh-solid breed-page__hero__overview__subtitle']")
    if len(tagging) == 1 :
        first = str(tagging[0].text)
        if any(s in first for s in weight_crazy)  :
            final['crazy_weight1'] = first

    if len(tagging) == 2 :
        first = str(tagging[0].text)
        second = str(tagging[1].text)
    
        if any(s in first for s in weight_crazy)  :
            final['crazy_weight1'] = first
        if any(s in second for s in weight_crazy) :
            final['crazy_weight2'] = second

    if len(tagging) == 3 :
        first = str(tagging[0].text)
        second = str(tagging[1].text)
        third = str(tagging[2].text)
        if any(s in first for s in weight_crazy)  :
            final['crazy_weight1'] = first
        if any(s in second for s in weight_crazy) :
            final['crazy_weight2'] = second
        if any(s in third for s in weight_crazy) :
            final['crazy_weight3'] = third

    #lifespan---------------------------------------------------------------------------------------------------------
    tagging = tag[2].find_elements_by_css_selector("p[class = 'f-16 my0 lh-solid breed-page__hero__overview__subtitle']")
    if len(tagging) == 1 :
        first = str(tagging[0].text)
        if any(s in first for s in weight_crazy)  :
            final['crazy_lifespan1'] = first

    if len(tagging) == 2 :
        first = str(tagging[0].text)
        second = str(tagging[1].text)
    
        if any(s in first for s in weight_crazy)  :
            final['crazy_lifespan1'] = first
        if any(s in second for s in weight_crazy) :
            final['crazy_lifespan2'] = second

    if len(tagging) == 3 :
        first = str(tagging[0].text)
        second = str(tagging[1].text)
        third = str(tagging[2].text)
        if any(s in first for s in weight_crazy)  :
            final['crazy_lifespan1'] = first
        if any(s in second for s in weight_crazy) :
            final['crazy_lifespan2'] = second
        if any(s in third for s in weight_crazy) :
            final['crazy_lifespan3'] = third

    df = df.append(final, ignore_index= True)
    time.sleep(random.randint(3, 4))
    
df.head()
# Out:
#                 breed_name              crazy_height1  \
# 0  Polish Lowland Sheepdog                        NaN
# 1               Pomeranian                        NaN
# 2       Poodle (Miniature)                        NaN
# 3        Poodle (Standard)  over 15 inches (standard)
# 4             Poodle (Toy)     No more than 10 inches
#
#                   crazy_weight1                   crazy_weight2 crazy_height2  \
# 0                           NaN                             NaN           NaN
# 1                           NaN                             NaN           NaN
# 2                           NaN                             NaN           NaN
# 3  60-70 pounds (male standard)  40-50 pounds (female standard)           NaN
# 4                           NaN                             NaN           NaN
#
#   crazy_height3 crazy_weight3
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# ...

# %%
breed = \
[['Affenpinscher',
  'https://www.akc.org/dog-breeds/affenpinscher/',
  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/30174107/Affenpinscher-copy-400x267.jpg'],
 ['Afghan Hound',
  'https://www.akc.org/dog-breeds/afghan-hound/',
  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/26151212/Afghan-Hound-standing-in-a-garden-400x267.jpg'],
 ['Airedale Terrier',
  'https://www.akc.org/dog-breeds/airedale-terrier/',
  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/30202205/Airedale-Terrier-standing-stacked-outdoors-400x267.jpg'],
 ['Akita',
  'https://www.akc.org/dog-breeds/akita/',
  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/13001904/Akita-On-White-01-400x267.jpg'],
 ['Alaskan Klee Kai',
  'https://www.akc.org/dog-breeds/alaskan-klee-kai/',
  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2021/01/29143827/Alaskan-Klee-Kai-standing-in-the-snow-attached-to-a-harness-400x267.jpg'],
 ['Alaskan Malamute',
  'https://www.akc.org/dog-breeds/alaskan-malamute/',
  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/13001815/Alaskan-Malamute-On-White-03-400x267.jpg'],
 ['American Bulldog',
  'https://www.akc.org/dog-breeds/american-bulldog/',
  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2020/01/14144341/American-Bulldog-standing-in-three-quarter-view-400x267.jpg'],
 ['American English Coonhound',
  'https://www.akc.org/dog-breeds/american-english-coonhound/',
  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/13001745/American-English-Coonhound-On-White-03-400x267.jpg'],
 ['American Eskimo Dog',
  'https://www.akc.org/dog-breeds/american-eskimo-dog/',
  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/13001724/American-Eskimo-Dog-On-White-01-400x267.jpg'],
 ['American Foxhound',
  'https://www.akc.org/dog-breeds/american-foxhound/',
  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/13001630/American-Foxhound-On-White-03-400x267.jpg'],
 ['American Hairless Terrier',
  'https://www.akc.org/dog-breeds/american-hairless-terrier/',
  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/18232608/American-Hairless-Terrier-standing-in-the-grass-on-lead-400x267.jpg'],
 ['American Leopard Hound',
  'https://www.akc.org/dog-breeds/american-leopard-hound/',
  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/13001556/American-Leopard-Hound-On-White-01-400x267.jpg'],
 ['American Staffordshire Terrier',
  'https://www.akc.org/dog-breeds/american-staffordshire-terrier/',
  'https://www.akc.org/wp-content/themes/akc/component-library/assets/img/1x1.trans.gif'],
 ['American Water Spaniel',
  'https://www.akc.org/dog-breeds/american-water-spaniel/',
  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/04160609/American-Water-Spaniel.1-400x267.jpg'],
 ['Anatolian Shepherd Dog',
  'https://www.akc.org/dog-breeds/anatolian-shepherd-dog/',
  'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11