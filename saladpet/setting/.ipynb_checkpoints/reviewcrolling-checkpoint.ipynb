# %%
## 네이버 웹툰 제목 끌고오기
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36'}

url = 'https://comic.naver.com/webtoon/weekday'
res = requests.get(url, headers = headers)
res.raise_for_status()
soup = BeautifulSoup(res.text, 'lxml')

filename = '웹툰이름2.csv'
f = open(filename, 'w', encoding='utf8', newline='')
writer = csv.writer(f)


hi = soup.find_all("a", attrs={"class" : "title"})
for h in hi :
    row_datas =h.get_text()
    data = row_datas.split('\n')
    print(data)
    writer.writerow(data)
    
    
    #col_name = ['title']
    #data = pd.DataFrame(row_data, columns = col_name)
    #print(data)
# Out:
# ['참교육']
# ['신의 탑']
# ['뷰티풀 군바리']
# ['윈드브레이커']
# ['팔이피플']
# ['소녀의 세계']
# ['장씨세가 호위무사']
# ['백수세끼']
# ['파이게임']
# ['앵무살수']
# ['만렙돌파']
# ['삼매경']
# ['잔불의 기사']
# ['더블클릭']
# ['요리GO']
# ['약초마을 연쇄살초사건']
# ['유일무이 로맨스']
# ['바퀴']
# ['칼가는 소녀']
# ['히어로메이커']
# ['결혼생활 그림일기']
# ['홍천기']
# ['영앤리치가 아니야!']
# ['물어보는 사이']
# ['오늘의 순정망화']
# ['꼬리잡기']
# ['ㅋㄷㅋㄷ만화']
# ['똑 닮은 딸']
# ['평범한 8반']
# ['리턴 투 플레이어']
# ['아, 쫌 참으세요 영주님!']
# ['아는 여자애']
# ['수영만화일기']
# ['장난감']
# ['황제와의 하룻밤']
# ['꿈의 기업']
# ['순정말고 순종']
# ['최후의 금빛아이']
# ['하루의 하루']
# ['와이키키 뱀파이어']
# ['야생천사 보호구역']
# ['모스크바의 여명']
# ['착한건 돈이된다']
# ['사랑의 헌옷수거함']
# ['선배, 그 립스틱 바르지 마요']
# ['왕따협상']
# ['백호랑']
# ['원하는 건 너 하나']
# ['이중첩자']
# ['또다시, 계약 부부']
# ['라서드']
# ['마지막 지수']
# ['사막에 핀 달']
# ['드로잉 레시피']
# ['중독연구소']
# ['살아간다']
# ['이탄국의 자청비']
# ['그림자 신부']
# ['모락모락 왕세자님']
# ['바로 보지 않는']
# ['개밥 먹는 남자']
# ['헬로맨스']
# ['오로지 오로라']
# ['트리거']
# ['기사님을 지켜줘']
# ['보살님이 캐리해!']
# ['말박왕']
# ['여신강림']
# ['덴큐']
# ['용사가 돌아왔다']
# ['한림체육관']
# ['엽총소년']
# ['하루만 네가 되고 싶어']
# ['사신소년']
# ...

# %%
## 네이버 스토어
import requests
from bs4 import BeautifulSoup
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36'}

url = 'https://smartstore.naver.com/soon-sik/products/4385637000?NaPm=ct%3Dkt7y1njc%7Cci%3D698c432465ad3745460d1410e24b8afac19c4fca%7Ctr%3Dslsl%7Csn%3D827360%7Chk%3D34c1fd1c1c28835e9363e7052a33b4642d17e2a1'
res = requests.get(url, headers = headers)
res.raise_for_status()
soup = BeautifulSoup(res.text, 'lxml')

hhh = soup.find('p', attrs = {'class':'_3hDJqJdj9e'})
hhh.get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-e5980e0ad527> in <module>
#      10
#      11 hhh = soup.find('p', attrs = {'class':'_3hDJqJdj9e'})
# ---> 12 hhh.get_text()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
## 브이랩 홈페이지
import requests
from bs4 import BeautifulSoup
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36'}

url = 'https://www.vlab.kr/goods/goods_view.php?goodsNo=1000000014&inflow=naver&NaPm=ct%3Dkt74nheg%7Cci%3Dc3e00a4a7e7bbe7bf47d1ca6b479c90c51a2d361%7Ctr%3Dslsl%7Csn%3D583995%7Chk%3D10ab11bbc1c1a8f1c79d359bf0229ee17902c407#reviews'
res = requests.get(url, headers = headers)
res.raise_for_status()
soup = BeautifulSoup(res.text, 'lxml')

soup.get_text()
#hhh = soup.find('td', attrs = {'class':'board_tit'})
#print(hhh)
# Out:
# '\n\n수의사와 함께하는 브랜드, 브이랩\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLOGIN\n\n\n\n\n\n\n\nCART (0)\nMYPAGE\nORDER\nSEARCH\n\nX\n\n\n\n검색폼\n\n\n\n\n\n\n\n\n\n\n\n최근검색어\n최근 검색어가 없습니다.\n\n\n\n\n닫기\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPREV\n\n\n\nALL\n\n\nBEST\n\n\nDOG\n\n\n\n커스터밀\n\n\n펫체크\n\n\n영양제\n\n\n유산균\n\n\n다이어트간식\n\n\n덴탈껌\n\n\n슬개골의류\n\n\n\n\nCAT\n\n\n\n펫체크\n\n\n영양제\n\n\n유산균\n\n\n다이어트간식\n\n\n\n\nDONATION\n\n\n\nNEXT\n\n\n\n\n\n\n\n\n\nPRODUCT\nALL\nBEST\nDOG\nCAT\nDONATION\n\n\n\n커스터밀\n펫체크\n영양겔\n유산균\n다이어트간식\n덴탈껌\n슬개골의류\n\n\n\n펫체크\n영양겔\n유산균\n다이어트간식\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHOME\n\xa0>\xa0\n\nALL\n\nALL\nBEST\nDOG\nCAT\nDONATION\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n   \n[17%] 고양이 영양제 브이랩 테이스트 플러스 헬스케
# ...

# %%
##네이버 쇼핑
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36'}

url = 'https://search.shopping.naver.com/catalog/18731948933?query=%EB%A7%88%EC%9D%B4%ED%8E%AB%EB%8B%A5%ED%84%B0%20%EA%B3%A0%EC%96%91%EC%9D%B4%20%EC%A2%85%ED%95%A9%20%EC%98%81%EC%96%91%EC%A0%9C%20%EB%84%A4%EB%B0%94%EC%97%90%ED%86%A0%EB%8B%89%20%ED%97%A4%EC%96%B4%EB%B3%BC&NaPm=ct%3Dkt862d20%7Cci%3D759e5516bb9e11aa8d24c351e565af1b754c7238%7Ctr%3Dslsl%7Csn%3D95694%7Chk%3Db2461932fa8eaa10905a4d579f574c9619912e99'
res = requests.get(url, headers = headers)
res.raise_for_status()
soup = BeautifulSoup(res.text, 'lxml')

#filename = '펫윈.csv'
#f = open(filename, 'w', encoding='utf8', newline='')
#writer = csv.writer(f)


aaa = soup.find_all('p', attrs = {"class":"reviewItems_text__XIsTc"})
for aa in aaa :
    row_datas = aa.get_text()
    data = row_datas.split('\n')
    print(data)
    #writer.writerow(data)
# Out:
# ['음수량이 부족한 냥이들을 위해 인 성분과 나트륨 함량을 낮춰 특별 포뮬러로 제조된 영양제라 마음에 들었다.  1BOX 양 30포 기준 450g 한달 먹을 양이고,개당 스틱형식의 포장으로 15g씩 들어 있다.하루에 1개 씩 급여해 주면된다.또한 먹기 편하게 츄르 처럼 짜서 주면 되기에너무 간편하게 급여가 가능한 영양제이다. 👉네바에토닉의 특별한 성분✔️코엔자임Q10 - 면역력 향상, 해독과정 도움✔️타피오카 - 혈류 및 혈액순환 개선✔️퀘르세틴 - 항염 작용, 혈압 조절 도움✔️브로콜리, 당근 - 비타민, 칼슘, 철분, 섬유질 보충✔️빌베리추출물 - 활성산소 제거 도움✔️글루코사민 -  신체밸런스 균형 도움✔️L-테아닌 - 스트레스 완화✔️이뮤노월 - 면역력 활성화/항염 및 항암 작용 도움 늘 사료와 습식을 주면서.. 과연 하루 적정하게 영양을 골고루 주고 있는가?생각하는데.. 그런 생각 고민 없이 그냥 짜먹는 종합영양제 네바에토닉를 하루에 1개씩 챙겨주면 될거 같다!!!성분을 보면 알듯이 필수영양들이 들어가 있어서 간편하게 급여할 수 있고, 늘 수분이 부족한 아이에게 수분 보충해 줄 수 있는 건강한 영양제 맛있게 챙겨줘야겠다.집사 만족하는 체험이다. ^^']
# ['저희집 냥이들은 길에서 구조된 냥이들이다보니 면연력이 약한데요😭둘째냥이는 접종을2번이나진행했지만 항체도거의생기지않아 최대한 면연력을 신경쓰고있어요!알약은 먹이기 너무힘든데 짜먹는영양제라니😻집사들이거정하는 헤어볼과 면연력 영양까지😻➖우선 제형은 일반츄르와 비슷했어요!너무 좋았던점은 물에 쉽게녹아 음수량을위해 물에풀어주기 쉬웠고,다른 첨가물을 넣지않아 믿음가고 내용물에서 직접들어간 재료를 쉽게 확인할수있었어요👍➖기호성이 너무좋아요...🤣첫째가 츄르도 가리고 정말정말까다로운데 순식간에 그릇설거지다했어요ㅋㅋㅋ➖무엇보다 성분!!다른 첨가물없이 만든게맘에들고 하루한포씩 간편하게 냥이들 영양까지챙겨줄수있어서 편해요:-)⭐영양제먹이기 힘든집사님들!⭐기호성,성분좋은 영양제찾으시는분들!⭐추천합니당']
# ...

# %%
import pandas as pd 
import pymysql 
import pymysql.cursors
import numpy as np
from scipy.stats import chisquare
from scipy import stats
import scipy as sp
import statsmodels.api as sm
from statsmodels.formula.api import ols, logit, glm
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
plt.rcParams['font.family'] = 'Malgun Gothic'

from konlpy.tag import Okt

df = pd.read_excel('C:/import/petwin.xlsx', header=None)

okt = Okt()
nouns = okt.nouns(df)
word_list = [x for x in nouns if len(x)>=2]
print(word_list)
# Out:
# ---------------------------------------------------------------------------
# JVMNotFoundException                      Traceback (most recent call last)
# <ipython-input-127-00b48ffe6086> in <module>
#      20 df = pd.read_excel('C:/import/petwin.xlsx', header=None)
#      21
# ---> 22 okt = Okt()
#      23 nouns = okt.nouns(df)
#      24 word_list = [x for x in nouns if len(x)>=2]
#
# C:\anaconda3\lib\site-packages\konlpy\tag\_okt.py in __init__(self, jvmpath, max_heap_size)
#      89     def __init__(self, jvmpath=None, max_heap_size=1024):
#      90         if not jpype.isJVMStarted():
# ---> 91             jvm.init_jvm(jvmpath, max_heap_size)
#      92
#      93         oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
#
# C:\anaconda3\lib\site-packages\konlpy\jvm.py in init_jvm(jvmpath, max_heap_size)
#      53     classpath = os.pathsep.join(f.format(*args) for f in folder_suffix)
#      54
# ---> 55     jvmpath = jvmpath or jpype.getDefaultJVMPath()
#      56
# ...

# %%
2 42 21
